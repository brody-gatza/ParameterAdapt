# %%
import numpy as np

# %%
prim_state = np.load(r'C:\GIT_Fork\ROMify\examples\1D_RDE\Injection_Files\10_inject_prim_state.npy')
print(prim_state)
# Out:
# [[2.56470983e+00]
#  [1.00000000e+01]
#  [5.06625000e+04]
#  [3.00000000e+02]
#  [1.27724300e-02]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [1.01362140e-01]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [8.85865430e-01]
#  [0.00000000e+00]]

# %%
prim_state[1] = 200
prim_state[2] = 101325
np.save(r'C:\GIT_Fork\ROMify\examples\1D_RDE\Injection_Files\200ms_1atm_inject_prim_state.npy',prim_state)
print(prim_state)
# Out:
# [[2.56470983e+00]
#  [2.00000000e+02]
#  [1.01325000e+05]
#  [3.00000000e+02]
#  [1.27724300e-02]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [1.01362140e-01]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [8.85865430e-01]
#  [0.00000000e+00]]
